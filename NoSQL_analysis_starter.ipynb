# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
num_docs = establishments.count_documents(query)
print(f"There are {num_docs} establishments that have a hygiene score of 20:")

# Display the first document in the results using pprint
pprint(establishments.find_one(query))
# Out:
# There are 41 establishments that have a hygiene score of 20:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65053db58c98e93456a90630'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
est_df = pd.DataFrame(establishments.find(query))

# Display the number of rows in the DataFrame
print(f"Dataframe has {len(est_df)} rows: ")
# Display the first 10 rows of the DataFrame
est_df.head(10)
# Out:
# Dataframe has 41 rows:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65053db58c98e93456a90630   110681                  0
# 1  65053db58c98e93456a909b6   612039                  0
# 2  65053db58c98e93456a90cc1   730933                  0
# 3  65053db58c98e93456a90eac   172735                  0
# 4  65053db58c98e93456a90ebe   172953                  0
# 5  65053db58c98e93456a9185d   512854                  0
# 6  65053db58c98e93456a91a7e  1537089                  0
# 7  65053db58c98e93456a92faa   155648                  0
# 8  65053db58c98e93456a933ec  1012883                  0
# 9  65053db58c98e93456a93bfb   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query1 = {'LocalAuthorityName': {'$regex': 'London'},
         'RatingValue': {'$gte': '4'}}

# Use count_documents to display the number of documents in the result
num_docs1 = establishments.count_documents(query1)
print(f"There are {num_docs1} London establishments with a rating equal or greater than 4: ")

# Display the first document in the results using pprint
pprint(establishments.find_one(query1))
# Out:
# There are 0 London establishments with a rating equal or greater than 4:
# None

# %%
# Convert the result to a Pandas DataFrame
est_df1 = pd.DataFrame(establishments.find(query1))

# Display the number of rows in the DataFrame
print(f"Dataframe has {len(est_df1)} rows: ")

# Display the first 10 rows of the DataFrame
est_df1.head(10)
# Out:
# Dataframe has 0 rows:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
pprint(establishments.find_one({'BusinessName': 'Penang Flavours'}, {'geocode.latitude', 'geocode.longitude'}))
# Out:
# {'_id': ObjectId('65054165f9fa27a59c072d3e'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query2 = {'RatingValue': 5,
          'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)},
          'geocode.longitude': {'$lte': {longitude + degree_search}, '$gte': (longitude - degree_search)}
          }
sort =  [('scores.Hygiene', 1)]


for result in establishments.find(query2).sort(sort).limit(5):
    pprint(result)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# /Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb Cell 17 line 1
#       <a href='vscode-notebook-cell:/Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> query2 = {'RatingValue': 5,
#      <a href='vscode-notebook-cell:/Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>           'geocode.latitude': {'$lte': (latitude + degree_search), '$gte': (latitude - degree_search)},
#      <a href='vscode-notebook-cell:/Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a>           'geocode.longitude': {'$lte': {longitude + degree_search}, '$gte': (longitude - degree_search)}
# ...

# %%
# Print the results
print('Number of rows in result: ', len(results))

pprint(results[0:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> # Print the results
# ----> <a href='vscode-notebook-cell:/Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> print('Number of rows in result: ', len(results))
#       <a href='vscode-notebook-cell:/Users/flynnlives/Documents/GitHub/DABC_noSQL_Challenge/NoSQL_analysis_starter.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> pprint(results[0:10])
#
# NameError: name 'results' is not defined

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
